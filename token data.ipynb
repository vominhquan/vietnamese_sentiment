# %%
import os
import time
from multiprocessing import Pool
from functools import partial
import pandas as pd
import json
import pyspark

from pyspark import SparkContext
from py4j.java_gateway import java_import
from pyspark.mllib.common import _to_java_object_rdd

# %%
# Import vnTokenizer from Java
java_import(sc._gateway.jvm, "vn.vitk.tok.Tokenizer")
Tokenizer = sc._jvm.vn.vitk.tok.Tokenizer
dataFolder = os.getcwd() + '/dat/tok'
token = Tokenizer(sc._jsc, dataFolder + "/lexicon.xml", dataFolder + "/regexp.txt")

# %%
topics = ['GiaoDuc', 'PhapLuat', 'TheGioi', 'TheThao', 'ThoiSu']

# %%
BATCH = 100

# %%
start = time.time()
for topic in topics:
    read_path = os.getcwd() + '/Data/Raw/' + topic
    write_path = os.getcwd() + '/Data/Tokenized/' + topic

    # resume
    list_tokened = os.listdir(write_path)
    list_raw = os.listdir(read_path)

    if(len(list_tokened)):
        last_file = list_tokened[-1]
        ind = list_tokened.index(last_file)
    else:
        ind = 0

    print(topic + ' Start at ' + str(ind))
    list_raw = list_raw[ind:]
    
    # Batching
    batch_indices = list_raw[0::BATCH]
    print('Number of remaining batches ', len(batch_indices))
    print('Each batch is ', BATCH)
    
    count_null = 0
    count_write = 0
    count = 0
    
    for b in range(len(batch_indices)): # in each batch
        
        # get all filename in its batch
        if(b < len(batch_indices)-1):
            start_index = list_raw.index(batch_indices[b])
            end_index = list_raw.index(batch_indices[b+1])
            list_file_name = list_raw[start_index:end_index]
        else:
            start_index = list_raw.index(batch_indices[b])
            list_file_name = list_raw[start_index:]            
        
        string_batch = ''
        for filename in list_file_name:
            # read data
            # read_time = time.time()

            with open(read_path+ '/'+ filename,'r') as fd:
                json_data = json.load(fd)

            title = json_data['title']
            title = title.replace('\t', ' ')
            title = title.replace('\n', ' ')

            content = json_data['content']
            content = content.replace('\t', ' ')
            content = content.replace('\n', ' ')

            title = ' '.join(title.split())
            content = ' '.join(content.split())

            if(content==title==""):
                count_null+=1
                bug_path = os.getcwd() + '/Data/log/null.txt' 
                with open(bug_path,'a') as fd:
                    fd.write(read_path+ '/'+ filename)
                    fd.write('\n')
                continue

            string_batch += filename + ' =========-----=========== '
            string_batch += title + ' '
            string_batch += content
            string_batch += ' ------=====-------------'
        
#         print(len(string_batch))
        string_batch_toked = token.tokenizeOneLine(string_batch)
        articles = string_batch_toked.split(' ------=====-------------')
#         print(len(articles))
        for article in articles:
            if(article):
#                 try:
                article_filename = article.split(' =========-----=========== ')[0].strip()
                article_content = article.split(' =========-----=========== ')[1].strip()
                # write data
                count_write += 1
                with open(write_path+ '/' + article_filename, 'w') as fd:
                    fd.write(article_content)
#                 except:
#                     pass
#                     print(string_batch)
#                     print('xxx----xxxx-x-x-xx-x-xxx-x-x-x-')
#                     print(article)
        count += BATCH
        if(count%1000==0):
            print('percent of topic', len(os.listdir(write_path))*100/len(os.listdir(read_path)))
            end = time.time()
            print('count null', count_null)
            print('count write', count_write)
            print('time', end - start)
            print('================')
            count_null = 0
            count_write = 0
            count = 0
# Out:
# GiaoDuc Start at 72918
# Number of remaining batches  21
# Each batch is  100
# percent of topic 97.3122656239574
# count null 225
# count write 775
# time 42.85903477668762
# percent of topic 97.3122656239574
# count null 235
# count write 765
# time 85.32816886901855
# PhapLuat Start at 53291
# Number of remaining batches  7
# Each batch is  100
# TheGioi Start at 2671
# Number of remaining batches  742
# Each batch is  100
# percent of topic 4.7500032543184805
# count null 6
# count write 994
# time 176.7807195186615
# percent of topic 6.041316827429999
# count null 8
# count write 992
# time 220.9223177433014
# percent of topic 7.333932127933768
# count null 7
# count write 993
# time 263.98820090293884
# percent of topic 8.618737064084039
# count null 13
# count write 987
# time 309.3694727420807
# percent of topic 9.911352364587808
# count null 7
# count write 993
# time 358.8764612674713
# percent of topic 11.19355384595358
# count null 15
# count write 985
# time 409.04786491394043
# percent of topic 12.436703505551867
# count null 45
# count write 955
# time 458.35152220726013
# percent of topic 13.627784069460173
# count null 85
# count write 915
# time 507.2550206184387
# percent of topic 14.911287278218195
# count null 14
# count write 986
# time 559.9420223236084
# percent of topic 16.151833483031982
# count null 47
# count write 953
# time 610.1956193447113
# percent of topic 17.3194829538798
# count null 103
# count write 897
# time 658.5863974094391
# percent of topic 18.41163223597714
# count null 161
# count write 839
# time 703.5701670646667
# percent of topic 19.57407479725596
# count null 107
# count write 893
# time 748.6793637275696
# percent of topic 20.563387615365592
# count null 240
# count write 760
# time 790.9071314334869
# percent of topic 21.464182970802256
# count null 308
# count write 692
# time 830.8951201438904
# percent of topic 22.505564884601867
# count null 200
# count write 800
# time 875.4040207862854
# percent of topic 23.78255945639864
# count null 19
# count write 981
# time 925.607715845108
# percent of topic 25.079079939079158
# count null 4
# count write 996
# time 973.7483341693878
# percent of topic 26.35997969305268
# count null 16
# count write 984
# time 1025.2436032295227
# percent of topic 27.655198448340947
# count null 5
# count write 995
# time 1079.3373148441315
# percent of topic 28.943908566667968
# count null 10
# count write 990
# time 1133.3131000995636
# percent of topic 30.22220486585699
# count null 18
# count write 982
# time 1187.4532418251038
# percent of topic 31.46014761588628
# count null 49
# count write 951
# time 1236.0380716323853
# percent of topic 32.27763241821898
# count null 372
# count write 628
# time 1274.0216677188873
# percent of topic 33.51557516824827
# count null 49
# count write 951
# time 1326.4141795635223
# percent of topic 34.79126801265279
# count null 20
# count write 980
# time 1373.867705821991
# percent of topic 36.07997813097981
# count null 10
# count write 990
# time 1429.3891541957855
# percent of topic 37.33874851928509
# count null 33
# count write 967
# time 1483.0991451740265
# percent of topic 38.58840681584463
# count null 40
# count write 960
# time 1535.3757338523865
# percent of topic 39.418908892099815
# count null 362
# count write 638
# time 1574.4995474815369
# percent of topic 40.32751461188998
# count null 302
# count write 698
# time 1615.6956493854523
# percent of topic 41.37410343525859
# count null 196
# count write 804
# time 1663.0105686187744
# percent of topic 42.52483045000716
# count null 116
# count write 884
# time 1713.3654067516327
# percent of topic 43.718514468699965
# count null 83
# count write 917
# time 1766.5663449764252
# percent of topic 44.929120943492016
# count null 70
# count write 930
# time 1821.067467212677
# percent of topic 46.14363260046081
# count null 67
# count write 933
# time 1875.8649158477783
# percent of topic 47.39589435180485
# count null 38
# count write 962
# time 1935.184142589569
# percent of topic 48.60650082659689
# count null 70
# count write 930
# time 1991.6158075332642
# percent of topic 49.81320211921219
# count null 73
# count write 927
# time 2045.2701988220215
# percent of topic 51.06286041577173
# count null 40
# count write 960
# time 2110.585133075714
# percent of topic 52.34115671496075
# count null 18
# count write 982
# time 2172.392296075821
# percent of topic 53.59992710326603
# count null 33
# count write 967
# time 2238.128893136978
# percent of topic 54.87041303810156
# count null 24
# count write 976
# time 2301.5282895565033
# percent of topic 56.1174678798766
# count null 42
# count write 958
# time 2360.0482046604156
# percent of topic 57.41008318038036
# count null 7
# count write 993
# time 2421.159019947052
# percent of topic 58.692284661746136
# count null 15
# count write 985
# time 2483.5659277439117
# percent of topic 59.96927923354291
# count null 19
# count write 981
# time 2539.8307042121887
# percent of topic 61.26059280665443
# count null 8
# count write 992
# time 2608.5220448970795
# percent of topic 62.5506046523737
# count null 9
# count write 991
# time 2674.8530638217926
# percent of topic 63.84061649809297
# count null 9
# count write 991
# time 2744.6694238185883
# percent of topic 65.11110243292849
# count null 24
# count write 976
# time 2811.4383714199066
# percent of topic 66.39460564168652
# count null 14
# count write 986
# time 2888.3924839496613
# percent of topic 67.67680712305228
# count null 15
# count write 985
# time 2957.1090972423553
# percent of topic 68.96812069616381
# count null 8
# count write 992
# time 3015.4851961135864
# percent of topic 70.26333945145208
# count null 5
# count write 995
# time 3085.4909703731537
# percent of topic 71.5572564793481
# count null 6
# count write 994
# time 3153.071700334549
# percent of topic 72.85507868942086
# count null 3
# count write 997
# time 3219.789183139801
# percent of topic 74.15159917210138
# count null 4
# count write 996
# time 3290.9070241451263
# percent of topic 75.4403092904284
# count null 10
# count write 990
# time 3354.70983171463
# percent of topic 76.72511422657867
# count null 13
# count write 987
# time 3423.6913690567017
# percent of topic 78.01512607229795
# count null 9
# count write 991
# time 3492.6746249198914
# percent of topic 79.30904310019396
# count null 6
# count write 994
# time 3558.535888195038
# percent of topic 80.60816703765897
# count null 2
# count write 998
# time 3634.2785975933075
# percent of topic 81.8994806107705
# count null 8
# count write 992
# time 3702.6957709789276
# percent of topic 83.19339763866651
# count null 6
# count write 994
# time 3771.132187604904
# percent of topic 84.48861639395477
# count null 5
# count write 995
# time 3829.7730798721313
# percent of topic 85.7747230574973
# count null 12
# count write 988
# time 3886.79501080513
# percent of topic 87.06082972103982
# count null 12
# count write 988
# time 3940.368491411209
# percent of topic 88.35084156675909
# count null 9
# count write 991
# time 4001.1422176361084
# percent of topic 89.62653441116362
# count null 20
# count write 980
# time 4058.8087623119354
# percent of topic 90.91914971166739
# count null 7
# count write 993
# time 4114.021287918091
# percent of topic 92.2000494656409
# count null 16
# count write 984
# time 4166.9340760707855
# percent of topic 93.48094921961443
# count null 16
# count write 984
# time 4220.180146217346
# percent of topic 94.75143515444995
# count null 24
# count write 976
# time 4273.9102737903595
# TheThao Start at 0
# Number of remaining batches  297
# Each batch is  100
# percent of topic 3.1992718201125983
# count null 51
# count write 949
# time 4323.70850944519
# percent of topic 6.418770859319691
# count null 45
# count write 955
# time 4365.4209241867065
# percent of topic 9.6416411017092
# count null 44
# count write 956
# time 4417.213464975357
# percent of topic 11.762127903448741
# count null 371
# count write 629
# time 4456.5285387039185
# percent of topic 14.448976839834136
# count null 203
# count write 797
# time 4498.288003921509
# percent of topic 17.624650237669826
# count null 58
# count write 942
# time 4545.773743152618
# percent of topic 20.7767252132286
# count null 65
# count write 935
# time 4596.221307516098
# percent of topic 23.932171391969796
# count null 64
# count write 936
# time 4649.997525930405
# percent of topic 27.03030711660992
# count null 81
# count write 919
# time 4699.849796295166
# percent of topic 29.82503455483262
# count null 171
# count write 829
# time 4748.189475536346
# percent of topic 32.852375012642014
# count null 102
# count write 898
# time 4798.349931001663
# percent of topic 36.06850284866669
# count null 46
# count write 954
# time 4853.492550373077
# percent of topic 39.29811549742103
# count null 42
# count write 958
# time 4908.709040403366
# percent of topic 42.52772814617537
# count null 42
# count write 958
# time 4959.591178655624
# percent of topic 45.720257559923134
# count null 53
# count write 947
# time 5013.5677921772
# percent of topic 48.91952938003573
# count null 51
# count write 949
# time 5065.631062269211
# percent of topic 52.13565721606041
# count null 46
# count write 954
# time 5117.88457608223
# percent of topic 55.405724303003744
# count null 30
# count write 970
# time 5184.049728393555
# percent of topic 58.51734484037353
# count null 77
# count write 923
# time 5239.2453553676605
# percent of topic 60.82324781714594
# count null 316
# count write 684
# time 5282.905552387238
# percent of topic 63.53369517580825
# count null 196
# count write 804
# time 5327.03117275238
# percent of topic 66.81387587229882
# count null 27
# count write 973
# time 5379.323719739914
# percent of topic 70.14462461652563
# count null 12
# count write 988
# time 5436.795388460159
# percent of topic 73.44840373529313
# count null 20
# count write 980
# time 5491.370729207993
# percent of topic 76.7049860095068
# count null 34
# count write 966
# time 5544.164760351181
# percent of topic 79.95482587735563
# count null 36
# count write 964
# time 5590.51735663414
# percent of topic 83.14061288473856
# count null 55
# count write 945
# time 5632.532087564468
# percent of topic 85.09928193372214
# count null 419
# count write 581
# time 5680.841255187988
# percent of topic 86.59946734989718
# count null 555
# count write 445
# time 5713.517085552216
# ThoiSu Start at 0
# Number of remaining batches  760
# Each batch is  100
# percent of topic 0.8958448607488209
# count null 320
# count write 680
# time 5781.789879322052
# percent of topic 1.8180380997549601
# count null 300
# count write 700
# time 5822.856272935867
# percent of topic 2.7020261902879876
# count null 329
# count write 671
# time 5859.282048225403
# percent of topic 3.5873316997338813
# count null 328
# count write 672
# time 5895.855556726456
# percent of topic 4.524016546781546
# count null 289
# count write 711
# time 5936.744418621063
# percent of topic 5.463336231654941
# count null 287
# count write 713
# time 5975.291178703308
# percent of topic 6.367085605880958
# count null 314
# count write 686
# time 6017.615271091461
# percent of topic 7.324849155534477
# count null 273
# count write 727
# time 6066.033111810684
# percent of topic 8.24309013780202
# count null 303
# count write 697
# time 6114.687829256058
# percent of topic 9.17055305245962
# count null 296
# count write 704
# time 6162.675540447235
# percent of topic 10.096698548204358
# count null 297
# count write 703
# time 6218.904177188873
# percent of topic 10.978051800911654
# count null 331
# count write 669
# time 6266.126249790192
# percent of topic 11.912101810133587
# count null 291
# count write 709
# time 6311.223255872726
# percent of topic 12.883039548915765
# count null 263
# count write 737
# time 6361.25332403183
# percent of topic 13.85792954443654
# count null 260
# count write 740
# time 6411.622380971909
# percent of topic 14.813058256264327
# count null 275
# count write 725
# time 6464.193242788315
# percent of topic 15.764234711353517
# count null 278
# count write 722
# time 6514.233421087265
# percent of topic 16.74307696361289
# count null 257
# count write 743
# time 6564.26319360733
# percent of topic 17.70084051326641
# count null 273
# count write 727
# time 6612.648421764374
# percent of topic 18.694174373567307
# count null 246
# count write 754
# time 6664.038335800171
# percent of topic 19.669064369088083
# count null 260
# count write 740
# time 6718.674404859543
# percent of topic 20.6847943509077
# count null 229
# count write 771
# time 6769.070984363556
# percent of topic 21.779569467499275
# count null 169
# count write 831
# time 6822.667551755905
# percent of topic 22.869074908439387
# count null 173
# count write 827
# time 6883.074958324432
# percent of topic 23.93486680894791
# count null 191
# count write 809
# time 6938.035310745239
# percent of topic 25.01515031749796
# count null 180
# count write 820
# time 6992.673799991608
# percent of topic 26.096751244960874
# count null 179
# count write 821
# time 7047.732107639313
# percent of topic 27.140147023950675
# count null 208
# count write 792
# time 7099.8534417152405
# percent of topic 28.211208600110663
# count null 187
# count write 813
# time 7152.420285701752
# percent of topic 29.23089083866888
# count null 226
# count write 774
# time 7205.6742198467255
# percent of topic 30.270334360920085
# count null 211
# count write 789
# time 7256.851677179337
# percent of topic 31.292651437304034
# count null 224
# count write 776
# time 7304.559582233429
# percent of topic 32.28466787869207
# count null 247
# count write 753
# time 7349.619281291962
# percent of topic 33.29908044159882
# count null 230
# count write 770
# time 7396.085802555084
# percent of topic 34.3240323558085
# count null 222
# count write 778
# time 7444.254742383957
# percent of topic 35.3634758780597
# count null 211
# count write 789
# time 7494.954152107239
# percent of topic 36.42926777856823
# count null 191
# count write 809
# time 7546.212247848511
# percent of topic 37.45290227386504
# count null 223
# count write 777
# time 7602.584555149078
# percent of topic 38.452823228730274
# count null 241
# count write 759
# time 7644.320183038712
# percent of topic 39.5028061022844
# count null 203
# count write 797
# time 7698.754299163818
# percent of topic 40.55937607040287
# count null 198
# count write 802
# time 7749.6706800460815
# percent of topic 41.62516797091139
# count null 191
# count write 809
# time 7805.891366004944
# percent of topic 42.69227729033278
# count null 190
# count write 810
# time 7862.439014196396
# percent of topic 43.72776855584539
# count null 214
# count write 786
# time 7910.17741060257
# percent of topic 44.84230495612995
# count null 154
# count write 846
# time 7960.000398874283
# percent of topic 45.90019234316128
# count null 197
# count write 803
# time 8011.707481622696
# percent of topic 46.95149263562828
# count null 202
# count write 798
# time 8057.229444980621
# percent of topic 48.009380022659606
# count null 197
# count write 803
# time 8102.146096229553
# percent of topic 49.11469449055411
# count null 161
# count write 839
# time 8147.473635673523
# percent of topic 50.22264379627434
# count null 159
# count write 841
# time 8200.499311447144
# percent of topic 51.32795826416884
# count null 161
# count write 839
# time 8245.981936216354
# percent of topic 52.442494664453406
# count null 154
# count write 846
# time 8292.498132944107
# percent of topic 53.54122203778358
# count null 166
# count write 834
# time 8336.505764484406
# percent of topic 54.666297789371065
# count null 146
# count write 854
# time 8376.417943000793
# percent of topic 55.81903933812874
# count null 125
# count write 875
# time 8418.602633237839
# percent of topic 56.942797670803365
# count null 147
# count write 853
# time 8460.402017354965
# percent of topic 58.08895212499671
# count null 130
# count write 870
# time 8511.686828613281
# percent of topic 59.25750270070877
# count null 113
# count write 887
# time 8569.239275932312
# percent of topic 60.41551392511791
# count null 121
# count write 879
# time 8622.524164676666
# percent of topic 61.53005032540247
# count null 154
# count write 846
# time 8669.935693025589
# percent of topic 62.66434800938002
# count null 139
# count write 861
# time 8719.792733669281
# percent of topic 63.84739019313361
# count null 102
# count write 898
# time 8771.612564086914
# percent of topic 65.00144916080416
# count null 124
# count write 876
# time 8819.503779172897
# percent of topic 66.14628619608463
# count null 131
# count write 869
# time 8878.01357626915
# percent of topic 67.2950754881037
# count null 128
# count write 872
# time 8931.027142763138
# percent of topic 68.46362606381577
# count null 113
# count write 887
# time 8980.26997923851
# percent of topic 69.65325534213369
# count null 97
# count write 903
# time 9033.552238464355
# percent of topic 70.83366268806155
# count null 104
# count write 896
# time 9086.448345899582
# percent of topic 71.99562616920929
# count null 118
# count write 882
# time 9136.329246044159
# percent of topic 73.14441546122836
# count null 128
# count write 872
# time 9193.886515378952
# percent of topic 74.31691829367902
# count null 110
# count write 890
# time 9250.95625591278
# percent of topic 75.44858113983085
# count null 141
# count write 859
# time 9304.386909008026
# percent of topic 76.58419624272126
# count null 138
# count write 862
# time 9364.950811862946
# percent of topic 77.74879456169472
# count null 116
# count write 884
# time 9426.034269332886
# percent of topic 78.95423286696703
# count null 85
# count write 915
# time 9481.246839761734
# percent of topic 80.02924669986562
# count null 90
# count write 816
# time 9536.93952012062
