# %%
import os
import pickle

import numpy as np
import pandas as pd
from sklearn import svm
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from bs4 import BeautifulSoup
from gensim.models import Word2Vec
from py4j.java_gateway import java_import
from pyspark.mllib.common import _to_java_object_rdd

# %%
with open('W2V_model.pickle', 'rb') as handle:
    model = pickle.load(handle)

# %%
# Import vnTokenizer from Java
java_import(sc._gateway.jvm, "vn.vitk.tok.Tokenizer")
Tokenizer = sc._jvm.vn.vitk.tok.Tokenizer
dataFolder = os.getcwd() + '/dat/tok'
token = Tokenizer(sc._jsc, dataFolder + "/lexicon.xml", dataFolder + "/regexp.txt")

# %%
df = pd.read_csv('export_labeling.csv')

# %%
df['mix'] = 'xxx ' + df.content

# %%
all_text = ' '.join(list(df['mix']))
all_text = BeautifulSoup(all_text, "lxml").text

tokened = token.tokenizeOneLine(all_text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-697c3a92a2b3> in <module>()
#       2 all_text = BeautifulSoup(all_text, "lxml").text
#       3
# ----> 4 tokened = token.tokenizeOneLine(all_text)
#
# NameError: name 'token' is not defined

# %%
df['content_toked'] = pd.Series(tokened.split('xxx')[1:])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-267142bb5fd6> in <module>()
# ----> 1 df['content_toked'] = pd.Series(tokened.split('xxx')[1:])
#
# NameError: name 'tokened' is not defined

# %%
def vectorize(text):
    sum_vec = np.zeros(100)
    for token in text.split():
        try:
            vec = model.wv.get_vector(token.lower())
            sum_vec += vec
        except KeyError:
            pass
    if np.count_nonzero(sum_vec)==0:
        return None
    else:
        return sum_vec

# %%
df['vec'] = df.content_toked.apply(vectorize)

df = df.dropna()

# %%
df[df.label!=0]
# Out:
#            id                                            content  \
# 0    24929249                                             ác quỷ
# 2    25097281                                            Cạn lời
# 4    25098148                                            Vô phúc
# 5    25105892                                            cạn lời
# 6    24926224                                           Mừng quá
# 7    25049905                                          Ngụy biện
# 8    24926213                                         Quá độc ác
# 10   25072944                                        Tởm lợm quá
# 13   24927439                                       Thật dã man.
# 14   24927706                                      Tội ác man rợ
# 20   25100697                                      Cô vợ dại quá
# 22   24926350                                     May quá, đã 18
# 27   25082608                                     Toà chính xác!
# 28   24929268                                    Lại An Giang...
# 30   25070886                                    Hay quá bạn :))
# 31   25077592                                    hết thời hổ báo
# 32   25080605                                    Tôi ủng hộ GRAB
# 33   24926164                                   Sớm đền tội thôi
# 34   24926211                                   Tin vui đầu năm.
# 36   24927512                                  quỷ đội lốt người
# 37   24927605                                  Sống làm gì nữa ?
# 39   24926521                                 công an Quá tài!
# 40   24926562                                 CA vn thật là hay.
# 42   24929105                                 Quá tàn nhẫn !!!!!
# 44   24926119                                Tin này vui hơn Tết
# 48   24926655                                nuôi ong tay áo rồi
# 52   25070155                                Kẻ này phải trả giá
# 54   25097691                                Có gì đó sai sai...
# 61   24926980                               Sao độc ác thế&nbsp;
# 62   24927596                               tội mấy&nbsp;đứa nhỏ
# ..        ...                                                ...
# 714  25082167  Vấn đề là phải tạo ra môi trường cạnh tranh cô...
# 715  25051071  Ai đi trong khu công nghiệp vĩnh lộc B vào ban...
# 716  25071063  Các bạn nữ bây giờ cũng thật quá dễ dãi với bả...
# 717  25080359  Muốn kiện người ta phải cung cấp được bằng chứ...
# 718  24927566  Tên con thường được bố mẹ đặt cho dựa vào cái ...
# 719  24927381  Trời đất, cha mẹ đặt cho cái tên Hữu Tình vì k...
# 722  25087708  Qua vụ việc này, rất mong chính quyền ban hành...
# 723  25051666  hãy thông cảm cho người tài xế cầm vô lăng xe ...
# 724  24926422  Tôi luôn tin vào tài năng phá trọng án thần tố...
# 725  25050709  Ai đi qua đoạn đường này mỗi ngày đều sẽ thấy ...
# 727  24930947  Chính xác là sống ảo, chỉ nhìn thấy những cảnh...
# 728  24926154  Vì tội ác của người này mà cả một gia đình tan...
# 729  25052883  Đồng ý đôi lúc có người từ đường nhỏ ra rất ẩu...
# 730  25056761  Sáng nay tôi tưởng tôi lên bàn thờ rồi chứ, tô...
# 731  24926183  Hay quá! Chiến công đầu năm của các chiến sĩ! ...
# 732  25083540  Tôi xin chân thành cảm ơn Uber và grab. Nhờ có...
# 733  24928573  Chiến công xuất sắc của Công an đầu năm Mậu Tu...
# 734  24927946  thứ nhất là dù có nhiều vết thương do có sự ch...
# 737  25051067  né xe chỉ là cái cớ để nguỵ biện cho bọn chả x...
# 738  24927505  Càng ngày có nhiều vụ thảm sát man rợ, sát nhâ...
# 739  25079509  Nhà Tèo có tiệm bida<br/>Bỗng dưng xuất hiện '...
# 740  24927609  Từ vụ án ở Bình Phước bây giờ đến vụ án ở tphc...
# 741  25051009  Những xe ben này đa số chở VLXK cho các công t...
# 742  25085891  Cần thiết cách ly những người nghiện ma ...
# 743  24926202  Công An TP.HCM quá giỏi và đầy trách nhiệm trư...
# 744  25082565  có rất nhiều hãng taxi nhé nên đừng bảo độc qu...
# 745  25055272  Hãy thử cảm giác lái xe sau hàng xe tải...
# 746  24928137  Vụ xả súng bên Mỹ cũng 19 tuổi, tôi nghi...
# 747  25097025  bất kỳ ai có hàm lượng ma túy đá trong ...
# 748  24926935  tội giết người. Tình tiết tăng nặng : gi...
#
#      content_length  label                                       article_link  \
# 0                 6     -1  https://vnexpress.net/tin-tuc/phap-luat/xxx-37...
# 2                 7     -1  https://vnexpress.net/tin-tuc/phap-luat/xxx-37...
# 4                 7     -1  https://vnexpress.net/tin-tuc/phap-luat/xxx-37...
# 5                 7     -1  https://vnexpress.net/tin-tuc/phap-luat/xxx-37...
# 6                 8      1  https://vnexpress.net/tin-tuc/phap-luat/xxx-37...
# 7                 9     -1  https://vnexpress.net/tin-tuc/phap-luat/xxx-37...
# 8                10     -1  https://vnexpress.net/tin-tuc/phap-luat/xxx-37...
# 10               11     -1  https://vnexpress.net/tin-tuc/phap-luat/xxx-37...
# 13               12     -1  https://vnexpress.net/tin-tuc/phap-luat/xxx-37...
# 14               13     -1  https://vnexpress.net/tin-tuc/phap-luat/xxx-37...
# 20               13     -1  https://vnexpress.net/tin-tuc/phap-luat/xxx-37...
# 22               14     -1  https://vnexpress.net/tin-tuc/phap-luat/xxx-37...
# 27               14      1  https://vnexpress.net/tin-tuc/phap-luat/xxx-37...
# 28               15     -1  https://vnexpress.net/tin-tuc/phap-luat/xxx-37...
# 30               15      1  https://vnexpress.net/tin-tuc/phap-luat/xxx-37...
# 31               15     -1  https://vnexpress.net/tin-tuc/phap-luat/xxx-37...
# 32               15      1  https://vnexpress.net/tin-tuc/phap-luat/xxx-37...
# 33               16      1  https://vnexpress.net/tin-tuc/phap-luat/xxx-37...
# 34               16      1  https://vnexpress.net/tin-tuc/phap-luat/xxx-37...
# 36               17     -1  https://vnexpress.net/tin-tuc/phap-luat/xxx-37...
# 37               17     -1  https://vnexpress.net/tin-tuc/phap-luat/xxx-37...
# 39               18      1  https://vnexpress.net/tin-tuc/phap-luat/xxx-37...
# 40               18      1  https://vnexpress.net/tin-tuc/phap-luat/xxx-37...
# 42               18     -1  https://vnexpress.net/tin-tuc/phap-luat/xxx-37...
# 44               19      1  https://vnexpress.net/tin-tuc/phap-luat/xxx-37...
# 48               19     -1  https://vnexpress.net/tin-tuc/phap-luat/xxx-37...
# 52               19     -1  https://vnexpress.net/tin-tuc/phap-luat/xxx-37...
# 54               19     -1  https://vnexpress.net/tin-tuc/phap-luat/xxx-37...
# 61               20     -1  https://vnexpress.net/tin-tuc/phap-luat/xxx-37...
# 62               20      1  https://vnexpress.net/tin-tuc/phap-luat/xxx-37...
# ..              ...    ...                                                ...
# 714             265     -1  https://vnexpress.net/tin-tuc/phap-luat/xxx-37...
# 715             267     -1  https://vnexpress.net/tin-tuc/phap-luat/xxx-37...
# 716             267     -1  https://vnexpress.net/tin-tuc/phap-luat/xxx-37...
# 717             269      1  https://vnexpress.net/tin-tuc/phap-luat/xxx-37...
# 718             279     -1  https://vnexpress.net/tin-tuc/phap-luat/xxx-37...
# 719             282     -1  https://vnexpress.net/tin-tuc/phap-luat/xxx-37...
# 722             288      1  https://vnexpress.net/tin-tuc/phap-luat/xxx-37...
# 723             291      1  https://vnexpress.net/tin-tuc/phap-luat/xxx-37...
# 724             294      1  https://vnexpress.net/tin-tuc/phap-luat/xxx-37...
# 725             299     -1  https://vnexpress.net/tin-tuc/phap-luat/xxx-37...
# 727             301     -1  https://vnexpress.net/tin-tuc/phap-luat/xxx-37...
# 728             307      1  https://vnexpress.net/tin-tuc/phap-luat/xxx-37...
# 729             316     -1  https://vnexpress.net/tin-tuc/phap-luat/xxx-37...
# 730             316     -1  https://vnexpress.net/tin-tuc/phap-luat/xxx-37...
# 731             323      1  https://vnexpress.net/tin-tuc/phap-luat/xxx-37...
# 732             333      1  https://vnexpress.net/tin-tuc/phap-luat/xxx-37...
# 733             342      1  https://vnexpress.net/tin-tuc/phap-luat/xxx-37...
# 734             345     -1  https://vnexpress.net/tin-tuc/phap-luat/xxx-37...
# 737             368     -1  https://vnexpress.net/tin-tuc/phap-luat/xxx-37...
# 738             375      1  https://vnexpress.net/tin-tuc/phap-luat/xxx-37...
# 739             411      1  https://vnexpress.net/tin-tuc/phap-luat/xxx-37...
# 740             416     -1  https://vnexpress.net/tin-tuc/phap-luat/xxx-37...
# 741             454      1  https://vnexpress.net/tin-tuc/phap-luat/xxx-37...
# 742             485      1  https://vnexpress.net/tin-tuc/phap-luat/xxx-37...
# 743             551      1  https://vnexpress.net/tin-tuc/phap-luat/xxx-37...
# 744             579      1  https://vnexpress.net/tin-tuc/phap-luat/xxx-37...
# 745             581     -1  https://vnexpress.net/tin-tuc/phap-luat/xxx-37...
# 746             785     -1  https://vnexpress.net/tin-tuc/phap-luat/xxx-37...
# 747             833     -1  https://vnexpress.net/tin-tuc/phap-luat/xxx-37...
# 748             946      1  https://vnexpress.net/tin-tuc/phap-luat/xxx-37...
# 740  1520689860030  xxx Từ vụ án ở Bình Phước bây giờ đến vụ án ở ...
# 741  1520689851571  xxx Những xe ben này đa số chở VLXK cho các cô...
# 742  1520689855860  xxx Cần thiết cách ly những người nghiện...
# 743  1520689863947  xxx Công An TP.HCM quá giỏi và đầy trách nhiệm...
# 744  1520689855988  xxx có rất nhiều hãng taxi nhé nên đừng bảo độ...
# 745  1520689851625  xxx Hãy thử cảm giác lái xe sau hàng xe ...
# 746  1520689860087  xxx Vụ xả súng bên Mỹ cũng 19 tuổi, tôi ...
# 747  1520689853593  xxx bất kỳ ai có hàm lượng ma túy đá tr...
# 748  1520689865670  xxx tội giết người. Tình tiết tăng nặng ...
#
# [507 rows x 7 columns]

# %%
df_copy = df.copy()

# %%
df = df_copy.copy()

X_train, X_test, y_train, y_test = train_test_split(df['vec'], df['label'], test_size=0.33)

clf = svm.SVC()
clf.fit(list(X_train), y_train)

y_pred = clf.predict(list(X_test))
y_true = y_test
confusion_matrix(y_true, y_pred)
# Out:
# array([[107,   2,   0],
#        [ 65,   5,   0],
#        [ 67,   0,   0]])

# %% [markdown]
# # no neutral

# %%
df = df_copy.copy()

df = df[df['label']!=0]

# %%
df = df[df['content_length']<100]

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn import neighbors
from sklearn.neural_network import MLPClassifier

# %% [markdown]
# # tuning

# %%
# SVM
parameters = {'C': np.arange(0.1, 2.0, 0.1), 'kernel':('linear', 'rbf', 'sigmoid'), }
tmp_model = svm.SVC()
svc = GridSearchCV(tmp_model, parameters)
svc.fit(list(df['vec']), df['label'])
svc_best_params_ = svc.best_params_
svc_best_score_ = svc.best_score_
print('SVM', svc_best_params_, svc_best_score_)


# MLPClassifier
parameters = {'activation':('identity', 'logistic', 'tanh', 'relu'),
              'hidden_layer_sizes': [(u, l) for u in np.arange(100, 200, 20) for l in np.arange(1,3)],
              'solver': ('lbfgs', )}
tmp_model = MLPClassifier()
mlp_model = GridSearchCV(tmp_model, parameters)
mlp_model.fit(list(df['vec']), df['label'])
mlp_best_params_ = mlp_model.best_params_
mlp_best_score_ = mlp_model.best_score_
print('MLPClassifier', mlp_best_params_, mlp_best_score_)


# Decision Tree
parameters = {'criterion': ('gini', 'entropy')}
tmp_model = DecisionTreeClassifier()
dt_model = GridSearchCV(tmp_model, parameters)
dt_model.fit(list(df['vec']), df['label'])
dt_best_params_ = dt_model.best_params_
dt_best_score_ = dt_model.best_score_
print('Decision Tree', dt_best_params_, dt_best_score_)


# Random Forest
parameters = {'criterion': ('gini', 'entropy'),
             'n_estimators': range(5,20)}
tmp_model = RandomForestClassifier()
rf_model = GridSearchCV(tmp_model, parameters)
rf_model.fit(list(X_train), y_train)
rf_best_score_ = rf_model.best_score_
rf_best_params_ = rf_model.best_params_
print('Random forest', rf_best_params_, rf_best_score_)


# KNN
parameters = {'metric': ('euclidean', 'cosine', 'minkowski'),
             'n_neighbors': range(5, 100, 5)}
tmp_model = neighbors.KNeighborsClassifier()
knn_model = GridSearchCV(tmp_model, parameters)
knn_model.fit(list(X_train), y_train)
knn_best_params_ = knn_model.best_params_
knn_best_score_ = knn_model.best_score_
print('KNN', knn_best_params_, knn_best_score_)
# Out:
# SVM {'C': 0.2, 'kernel': 'linear'} 0.698170731707317
# MLPClassifier {'activation': 'tanh', 'hidden_layer_sizes': (120, 1), 'solver': 'lbfgs'} 0.7286585365853658
# Decision Tree {'criterion': 'entropy'} 0.6646341463414634
# Random forest {'criterion': 'gini', 'n_estimators': 13} 0.5410821643286573
# KNN {'metric': 'cosine', 'n_neighbors': 10} 0.5671342685370742

# %% [markdown]
# # 70 - 30 train test

# %%
X_train, X_test, y_train, y_test = train_test_split(df['vec'], df['label'], test_size=0.33)

# SVM
svm_model = svm.SVC(**svc_best_params_)
svm_model.fit(list(X_train), y_train)

y_pred = svm_model.predict(list(X_test))
y_true = y_test
print('SVM')
print(confusion_matrix(y_true, y_pred))
print(accuracy_score(y_true, y_pred))


# MLPClassifier
mlp_model = MLPClassifier(**mlp_best_params_)
mlp_model.fit(list(X_train), y_train)

y_pred = mlp_model.predict(list(X_test))
y_true = y_test
print('MLPClassifier')
print(confusion_matrix(y_true, y_pred))
print(accuracy_score(y_true, y_pred))


# DT
dt_model = DecisionTreeClassifier(**dt_best_params_)
dt_model.fit(list(X_train), y_train)

y_pred = dt_model.predict(list(X_test))
y_true = y_test
print('Decision Tree')
print(confusion_matrix(y_true, y_pred))
print(accuracy_score(y_true, y_pred))

# Random Forest
rf_model = RandomForestClassifier(**rf_best_params_)
rf_model.fit(list(X_train), y_train)

y_pred = rf_model.predict(list(X_test))
y_true = y_test
print('Random forest')
print(confusion_matrix(y_true, y_pred))
print(accuracy_score(y_true, y_pred))

# KNN
knn_model = neighbors.KNeighborsClassifier(**knn_best_params_)
knn_model.fit(list(X_train), y_train)

y_pred = knn_model.predict(list(X_test))
y_true = y_test
print('KNN')
print(confusion_matrix(y_true, y_pred))
print(accuracy_score(y_true, y_pred))
# Out:
# SVM
# [[48 13]
#  [18 30]]
# 0.7155963302752294
# MLPClassifier
# [[52  9]
#  [18 30]]
# 0.7522935779816514
# Decision Tree
# [[39 22]
#  [19 29]]
# 0.6238532110091743
# Random forest
# [[54  7]
#  [27 21]]
# 0.6880733944954128
# KNN
# [[59  2]
#  [28 20]]
# 0.7247706422018348

# %% [markdown]
# # 10 fold cross validation

# %%
kf = KFold(n_splits=10)
X = df['vec'].tolist()
y = df['label'].tolist()

svm_result = []
mlp_result = []
dt_result = []
rf_result = []
knn_result = []

for train_index, test_index in kf.split(X):
    X_train, X_test = [X[i] for i in train_index], [X[i] for i in test_index]
    y_train, y_test = [y[i] for i in train_index], [y[i] for i in test_index]
    
    
    # SVM
    svm_model = svm.SVC(**svc_best_params_)
    svm_model.fit(list(X_train), y_train)

    y_pred = svm_model.predict(list(X_test))
    y_true = y_test
    svm_result.append(accuracy_score(y_true, y_pred))


    # MLPClassifier
    mlp_model = MLPClassifier(**mlp_best_params_)
    mlp_model.fit(list(X_train), y_train)

    y_pred = mlp_model.predict(list(X_test))
    y_true = y_test
    
    mlp_result.append(accuracy_score(y_true, y_pred))

    # DT
    dt_model = DecisionTreeClassifier(**dt_best_params_)
    dt_model.fit(list(X_train), y_train)

    y_pred = dt_model.predict(list(X_test))
    y_true = y_test
    
    dt_result.append(accuracy_score(y_true, y_pred))
    
    # Random Forest
    rf_model = RandomForestClassifier(**rf_best_params_)
    rf_model.fit(list(X_train), y_train)

    y_pred = rf_model.predict(list(X_test))
    y_true = y_test
    
    rf_result.append(accuracy_score(y_true, y_pred))

    # KNN
    knn_model = neighbors.KNeighborsClassifier(**knn_best_params_)
    knn_model.fit(list(X_train), y_train)

    y_pred = knn_model.predict(list(X_test))
    y_true = y_test
    
    knn_result.append(accuracy_score(y_true, y_pred))

# %%
print('SVM')
print(np.mean(svm_result))

print('MLPClassifier')
print(np.mean(mlp_result))

print('Decision Tree')
print(np.mean(dt_result))

print('Random forest')
print(np.mean(rf_result))

print('KNN')
print(np.mean(knn_result))
# Out:
# SVM
# 0.6890151515151516
# MLPClassifier
# 0.6981060606060606
# Decision Tree
# 0.5943181818181819
# Random forest
# 0.6891098484848485
# KNN
# 0.7253787878787878

# %% [markdown]
# # Some test case

# %%
svm_model = svm.SVC(**svc_best_params_)
svm_model.fit(df['vec'].tolist(), df['label'])
# Out:
# SVC(C=0.2, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
with open('SVM_model.pickle', 'wb') as handle:
    pickle.dump(svm_model, handle)

# %%
with open('SVM_model.pickle', 'rb') as handle:
    svm_model = pickle.load(handle)

# %%
input_text = 'Toà chính xác'
input_text_tokened = token.tokenizeOneLine(input_text)
print(input_text_tokened)

input_vec = vectorize(input_text_tokened)
print(input_vec)

svm_model.predict([input_vec])
# Out:
# Toà chính_xác
# [ 1.04086304 -1.92496395 -2.2725938  -3.36352062  0.65497446 -1.0380941
#  -1.40365517 -1.23997307 -2.34971216 -4.96927071  5.78147244 -0.37644911
#   1.36498615 -0.45285167  3.99076641  0.37398171  0.29981311  4.04796124
#   2.52687651  1.0552505  -0.709086    2.65707654  0.50446248  4.54734731
#   1.70417474 -3.06812149  1.31861359  1.1428055  -0.88251288  0.46178843
#  -0.88175142 -1.4287641   0.22639611  4.46257627  3.52507997 -0.01099262
#   2.08479345  1.71934464 -4.09721231  1.71379673 -0.91186213  0.42443816
#  -2.60398644  0.96475387  1.04659924 -0.68887708  1.74847394 -0.86631691
#  -2.46199211  5.4675169   1.93725976 -2.42202592  0.71491751  0.10406733
#   2.26181099 -0.93562829 -3.57759911 -1.3361131  -0.45010722  0.45893703
#  -3.74703455 -1.9961049   0.0588237   0.65915304  2.71249878 -2.35377049
#  -1.28461584 -4.05415544 -2.00214553  2.3623054  -0.99852804 -1.18645543
#  -0.89682198 -2.93126106 -0.2420294  -1.87509593 -1.97272527 -2.02930868
#   6.22473693 -2.78950357  1.13638377  1.86631429  2.73205739 -2.20342529
#  -0.56123258  2.04727554  0.72360325  0.92790476 -0.69222152 -0.10260391
#  -0.67607756 -1.45078284  1.78497571 -0.00830281 -2.16620862 -2.67472762
#   1.48371381  1.1601913  -0.68702266  1.18910748]
# array([1])

# %%
input_text = 'phóng thích'
print(input_text)

# %%
model.wv.most_similar('toà')
# Out:
# [('tòa', 0.7758179903030396),
#  ('phiên_toà', 0.6296157836914062),
#  ('hđxx', 0.553084671497345),
#  ('toà_án', 0.5176868438720703),
#  ('phúc_thẩm', 0.5169740915298462),
#  ('tòa_trọng_tài', 0.49995505809783936),
#  ('toà_trọng_tài', 0.49825742840766907),
#  ('giám_đốc_thẩm', 0.4915924668312073),
#  ('tài_phiệt', 0.48819756507873535),
#  ('anthem_inc', 0.47171491384506226)]

# %%
model.wv.most_similar('tòa')
# Out:
# [('toà', 0.77581787109375),
#  ('nếu_tòa', 0.6361499428749084),
#  ('tu_chính', 0.6249154806137085),
#  ('lập_pháp', 0.5303572416305542),
#  ('giám_đốc_thẩm', 0.5277676582336426),
#  ('sputnik_tòa', 0.5262762308120728),
#  ('toà_án', 0.526037871837616),
#  ('cao_tầng', 0.5111631155014038),
#  ('căn', 0.4936997890472412),
#  ('xử', 0.4921284317970276)]

# %%
model.wv.most_similar('trắc_nghiệm')
# Out:
# [('thi_trắc_nghiệm', 0.5748363733291626),
#  ('hình_học', 0.5364856719970703),
#  ('đáp_án', 0.5322859287261963),
#  ('chính_tả', 0.5321452617645264),
#  ('mk', 0.5043061971664429),
#  ('-53-65', 0.4993148744106293),
#  ('quiz', 0.48665499687194824),
#  ('vựng', 0.48498111963272095),
#  ('thuyết_tương_đối', 0.4842168390750885),
#  ('giải_nghĩa', 0.4841591715812683)]

# %%
df[df.content.str.contains('chính')]
# Out:
#            id                                            content  \
# 27   25082608                                     Toà chính xác!
# 505  25074608  nghiện chứ ca sĩ gi? ai công nhận đâu, dùng từ...
#
#      content_length  label                                       article_link  \
# 27               14      1  https://vnexpress.net/tin-tuc/phap-luat/xxx-37...
# 505              96      1  https://vnexpress.net/tin-tuc/phap-luat/xxx-37...
#
#        last_update                                                mix  \
# 27   1520689855946                                 xxx Toà chính xác!
# 505  1520689851981  xxx nghiện chứ ca sĩ gi? ai công nhận đâu, dùn...
#
#                                          content_toked  \
# 27                                    Toà chính_xác !
# 505   nghiện chứ ca_sĩ gi ? ai công_nhận đâu , dùng...
#
#                                                    vec
# 27   [-2.32006072998, -1.82127258927, -2.2872030613...
# 505  [-15.8777293116, 3.46057801694, -10.4677679464...

# %%
df[df.label==1]
# Out:
#            id                                            content  \
# 6    24926224                                           Mừng quá
# 27   25082608                                     Toà chính xác!
# 30   25070886                                    Hay quá bạn :))
# 32   25080605                                    Tôi ủng hộ GRAB
# 33   24926164                                   Sớm đền tội thôi
# 34   24926211                                   Tin vui đầu năm.
# 39   24926521                                 công an Quá tài!
# 40   24926562                                 CA vn thật là hay.
# 44   24926119                                Tin này vui hơn Tết
# 62   24927596                               tội mấy&nbsp;đứa nhỏ
# 67   25097640                              Cô vợ của năm đây rồi
# 69   24926380                             Hên quá đủ 18 tuổi rồi
# 70   24926636                             Mừng quá! 18 tuổi rồi.
# 76   24926126                            Hoan hô công an Tp.HCM.
# 77   24926353                            May mà nó đã đủ 18 tuổi
# 78   24927037                            Các chú công an hay quá
# 83   24926279                           Hy vọng hắn trên 18 tuổi
# 91   24926529                          Cong an bay gio gioi qua!
# 441  1520689851371  xxx Cám ơn các chiến sĩ. Chúc các anh mau bình...
# 442  1520689853743  xxx Có lẽ do hoàn cảnh cô gái phải sa vào hoàn...
# 451  1520689864131  xxx Côn an Việt Nam giỏi thiệt. Cảm ơn các anh...
# 452  1520689865597  xxx Tin vui năm mới, từ hôm qua nay chỉ mon...
# 456  1520689855975  xxx Tôi ủng hộ Vinasun kiện Grap và cả Uber nữ...
# 458  1520689851601  xxx Hy vọng các tài xế có tâm , coi trọng tính...
# 460  1520689851369  xxx cần phải xử nghiêm, tránh tình trạng không...
# 465  1520689864136  xxx Các anh quá xuất sắc. Chúc các anh l...
# 467  1520689860128  xxx Hung thủ đã bị bắt và sẽ phải đền tội.cầu ...
# 473  1520689863931  xxx Tên giết người quá nguy hiểm, nhưng các ch...
# 474  1520689863972  xxx Hoan hô các chiến sĩ công an, chúc các anh...
# 475  1520689856006  xxx Công an VN giỏi thật, cảm ơn các Anh đã nh...
# 476  1520689860224  xxx Cảnh sát quá giỏi. Gia đình nạn nhân quá đ...
# 477  1520689865713  xxx mong pháp luật có hình phạt thích đáng với...
# 480  1520689865626  xxx &nbsp;Cám ơn các anh công an không quản lễ...
# 481  1520689860148  xxx Toàn bộ các lực lượng đã tham gia phối hợp...
# 482  1520689860078  xxx Ko có giới hạn hành vi phòng vệ bạn ơi, ch...
# 484  1520689851356  xxx bọn này quá manh động sẵn sàng gây án. các...
# 485  1520689863961  xxx Đừng bao giờ gây nên tội ác , sẽ không bao...
# 486  1520689853709  xxx Học hết cấp 3 cố làm ca sĩ hả em? Trước kh...
# 489  1520689867709  xxx Tôi đoán 2 ngày sẽ bắt được kẻ nghi phạm, ...
# 503  1520689851720  xxx Giờ thì ko cần thủ tục nữa. Mà ly hôn nhan...
# 505  1520689851981  xxx nghiện chứ ca sĩ gi? ai công nhận đâu, dùn...
# 510  1520689863891  xxx Nói không phải nịnh Công An Việt Nam mình ...
#
#                                          content_toked  \
# 6                                            Mừng quá
# 27                                    Toà chính_xác !
# 30                                   Hay quá bạn : ))
# 32                                    Tôi ủng_hộ GRAB
# 33                                   Sớm đền_tội thôi
# 34                                  Tin_vui đầu năm .
# 39                             công_an Qua ́ ta ̀ i !
# 40                                CA vn thật là hay .
# 44                                Tin này vui hơn Tết
# 62                                  tội mấy   đứa nhỏ
# 67                              Cô vợ của năm đây rồi
# 69                             Hên quá đủ 18 tuổi rồi
# 70                           Mừng quá ! 18 tuổi rồi .
# 76                           Hoan_hô công_an Tp.HCM .
# 77                            May_mà nó đã đủ 18 tuổi
# 78                            Các chú công_an hay quá
# 83                           Hy_vọng hắn trên 18 tuổi
# 91                         Cong an bay gio gioi qua !
# 92                          May là hắn vừa đủ 18 tuổi
# 93                          Ơn giời nó đã 18 tuổi rồi
# 97                         Mong_chờ tin này hwa tới h
# 98                        Công_an Việt_Nam giỏi quá !
# 104                       Ơn trời kẻ thủ ác đã bị tóm
# 108                      Chúc các anh mau bình_phục !
# 109                            Chuc ông chông may man
# 116                     Bên thắng vẫn là khách hàng .
# 123                    Vô tù luyện giọng nha a trai .
# 125                   Nhanh quá , công_an VN tài thật
# 126                   Mừng vì nó vừa tròn 18 tuổi ...
# 128                   Tài_tình , tuyệt quá các anh ơi
# ..                                                 ...
# 407   Mấy hôm_nay tôi chỉ chờ_đợi , mong_ngóng tin ...
# 408   Hô hô .. chạy đâu cho thoát hả em .. Hoan_hô ...
# 411   cám_ơn các anh đã bắt được tên giết người dã_...
# 418   Hãng taxi có bao_giờ nghĩ đến giảm bớt giá và...
# 425   hay quá , chúc_mừng chiến_công của lực_lượng ...
# 440   Quá khen cho trinh_sát Việt rất là tài_năng n...
# 441   Cám_ơn các chiến_sĩ . Chúc các anh mau bình_p...
# 442   Có_lẽ do hoàn_cảnh cô gái phải sa vào hoàn cả...
# 451   Côn an Việt_Nam giỏi thiệt . Cảm_ơn các anh ....
# 452   Tin_vui năm mơ ́ i , tư ̀ hôm_qua nay chi ̉ m...
# 456   Tôi ủng_hộ Vinasun kiện Grap và cả Uber nữa ....
# 458   Hy_vọng các tài_xế có tâm , coi_trọng tính_mạ...
# 460   cần phải xử nghiêm , tránh tình_trạng không a...
# 465   Ca ́ c anh qua ́ xuâ ́ t să ́ c . Chu ́ c ca ...
# 467   Hung_thủ đã bị bắt và sẽ phải đền_tội . cầu_m...
# 473   Tên giết người quá nguy_hiểm , nhưng các chiế...
# 474   Hoan_hô các chiến_sĩ công_an , chúc các anh n...
# 475   Công_an VN giỏi thật , cảm_ơn các Anh đã nhan...
# 476   Cảnh_sát quá giỏi . Gia_đình nạn_nhân quá_đán...
# 477   mong pháp_luật có hình_phạt thích_đáng với tê...
# 480     Cám_ơn các anh công_an không quản lễ tết là...
# 481   Toàn_bộ các lực_lượng đã tham_gia phối_hợp rấ...
# 482   Ko có giới_hạn hành_vi phòng_vệ bạn ơi , chỉ ...
# 484   bọn này quá manh_động sẵn_sàng gây án . các c...
# 485   Đừng bao_giờ gây nên tội_ác , sẽ không bao_gi...
# 486   Học hết cấp 3 cố làm ca_sĩ hả em ? Trước khi ...
# 489   Tôi đoán 2 ngày sẽ bắt được kẻ nghi phạm , mớ...
# 503   Giờ thì ko cần thủ_tục nữa . Mà ly_hôn nhanh ...
# 505   nghiện chứ ca_sĩ gi ? ai công_nhận đâu , dùng...
# 510   Nói không phải nịnh Công_An_Việt_Nam mình đứn...
#
#                                                    vec
# 6    [0.350542515516, 0.597414374352, 0.22443556785...
# 27   [-2.32006072998, -1.82127258927, -2.2872030613...
# 30   [-6.59535965323, 2.57714438438, -2.30702804029...
# 32   [-5.38799283653, 1.40645685606, -1.87748279423...
# 33   [-1.64083902282, -2.92613292485, -0.1233732998...
# 34   [2.01233011484, 2.00089620019, 3.68940339983, ...
# 39   [-8.23035168648, 3.88569267839, 4.20050807018,...
# 40   [-3.61269539595, -2.6696883142, -6.16903573275...
# 44   [-5.31304593384, 1.04110825062, 5.38951149583,...
# 62   [4.44041395187, 1.15158653259, 1.22274839878, ...
